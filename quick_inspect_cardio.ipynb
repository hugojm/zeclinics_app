# %%
import os
import numpy as np
from PIL import Image
cwd = os.getcwd()
f = os.path.join(cwd, '20210212_p1_2_004', '20210212_p1_2_004_569.npy')
im = np.load(f)
print(im.shape)
pix = np.array(im)
print('max', np.max(pix), 'min', np.mean(pix))
Image.fromarray(pix)
#im = PIL.Image.fromarray(np.uint8(pix))
# Out:
# (482, 408)
# max 28426 min 1082.0631661378245
# <PIL.Image.Image image mode=I;16 size=408x482 at 0x10DE3FC70>
